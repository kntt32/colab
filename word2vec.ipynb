# %% [markdown]
# <a href="https://colab.research.google.com/github/kntt32/colab/blob/main/word2vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch.nn as nn
import matplotlib as plt

class Model(nn.Module):
  def __init__(self):
      nn.Module.__init__(self)
      self.word_box = WordBox()
      self.corpus = []

  def add_corpus(self, corpus: str):
    self.word_box.add_words_from_str(corpus)
    # self.corpus.append()

class WordBox:
  def __init__(self):
    self.words = []

  def add_words(self, words: list):
    self.words.from_list(words)

  def add_words_from_str(self, string):
    word = ""
    for char in string.strip():
      if char.isalnum():
        word += char
      else:
        if len(word) != 0:
            self.words.append(Word(word))
        word = ""
        if not char.isspace():
            self.words.append(Word(char))

  def __str__(self):
    string = "WordBox["
    for word in self.words:
      string += str(word) + ", "
    string += "]"
    return string

class Word:
  def __init__(self, word: str):
    self.word = word

  def __str__(self):
    return f"Word(\"{self.word}\")"

box = WordBox()
box.add_words_from_str("Hello, World!")
print(box)
# Out:
# WordBox[Word("Hello"), Word(","), Word("World"), Word("!"), ]
